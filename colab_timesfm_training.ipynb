# %% [markdown]
# # TimesFM 2.5 Training on Google Colab
#
# Train TimesFM 2.5 200M on FREE T4 GPU (16GB memory)

# %% [markdown]
# ## Step 1: Check GPU

# %%
# !nvidia-smi

# %% [markdown]
# ## Step 2: Install Dependencies

# %%
# !pip install -q transformers peft torch pandas numpy pyyaml
# !pip install -q accelerate  # For device_map optimization

import torch
print(f"PyTorch: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")

# %% [markdown]
# ## Step 3: Mount Google Drive & Upload Code

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Step 4: Setup Environment

# %%
import sys
import os

# Add your project to path
project_path = '/content/drive/MyDrive/stockvoli-research'
if project_path not in sys.path:
    sys.path.append(project_path)
    os.chdir(project_path)

print(f"Working directory: {os.getcwd()}")
print(f"Files in directory:")
# !ls -la

# %% [markdown]
# ## Step 5: Verify Data is Available

# %%
import os
from pathlib import Path

processed_dir = Path('data/processed')
if processed_dir.exists():
    files = list(processed_dir.glob('*_processed.csv'))
    print(f"✅ Found {len(files)} processed stock files")
else:
    print(f"❌ Processed data directory not found!")
    print(f"Please upload your processed data to: {processed_dir}")

# %% [markdown]
# ## Step 6: Start Training (T4 GPU - 16GB)

# %%
# Set CUDA memory management
import os
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

# Run training script
# !python src/model_training_fixed.py

# %% [markdown]
# ## Step 7: Monitor Training Progress

# %%
# Monitor GPU usage
# !nvidia-smi -l 2  # Update every 2 seconds

# Check training logs
# !tail -f experiments/model_training.log
